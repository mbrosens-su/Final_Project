# %%
import pandas as pd
import googlemaps
import folium

# %%
api_key = 'AIzaSyBGPrUO2TnedZZ3PJumc-ns_2EprRjMLqU'
gmaps_key = googlemaps.Client(key = api_key)

df = pd.read_csv("Teams.csv")

# %%
city = input("What is your address: ")

geocode_result = gmaps_key.geocode(city)
lat = geocode_result[0]["geometry"]["location"]["lat"]
lon = geocode_result[0]["geometry"]["location"]["lng"]
# Out:
# What is your address: Friendswood, Tx

# %%
CENTER = (lat,lon)
map1 = folium.Map(location=CENTER, zoom_start=7)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e3b32d6574be> in <module>
#       7 long = []
#       8 for i in range(0, listlen):
# ----> 9     long.append(long['Long'])
#      10
#      11 name = []
#
# TypeError: list indices must be integers or slices, not str

# %%
sport = input("Pick a sport:")
CENTER = (lat,lon)
map1 = folium.Map(location=CENTER, zoom_start=7)
marker = folium.Circle(location=CENTER, radius=160934,color='#3186cc',fill_color='#3186cc')
map1.add_child(marker)
map1
teams = df[df['Sport'] == sport]
for row in teams.to_records():
    pos = (row['Lat'],row['Long'])
    message = "%s" % (row['Name'])
    marker = folium.Marker(location=pos, 
                    popup=message
                            )
    map1.add_child(marker)
map1
# Out:
# Pick a sport:Soccer
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-33ec66163cee> in <module>
# ----> 1 google.maps.computeDistanceBetween(CENTER, pos, 100)
#
# NameError: name 'google' is not defined
