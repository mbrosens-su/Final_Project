# %%
import requests
import pandas as pd
import folium
import warnings
import googlemaps
warnings.filterwarnings('ignore')
import googlemaps

# %%
gmaps_key = googlemaps.Client(key = 'AIzaSyBGPrUO2TnedZZ3PJumc-ns_2EprRjMLqU')

# %%
sport_teams = pd.read_csv('Teams.csv')
sport_teams
# Out:
#           Sport League             City             State  \
# 0    Basketball    NBA          Atlanta           Georgia
# 1    Basketball    NBA           Boston     Massachusetts
# 2    Basketball    NBA         Brooklyn          New York
# 3    Basketball    NBA        Charlotte    North Carolina
# 4    Basketball    NBA          Chicago          Illinois
# 5    Basketball    NBA        Cleveland              Ohio
# 6    Basketball    NBA           Dallas             Texas
# 7    Basketball    NBA           Denver          Colorado
# 8    Basketball    NBA          Detroit          Michigan
# 9    Basketball    NBA    San Francisco        California
# 10   Basketball    NBA          Houston             Texas
# 11   Basketball    NBA     Indianapolis           Indiana
# 12   Basketball    NBA      Los Angeles        California
# 13   Basketball    NBA      Los Angeles        California
# 14   Basketball    NBA          Memphis         Tennessee
# ...

# %%
sport = input("enter your favorite sport (pick between Basketball, Soccer, Football, Baseball and Hockey):")
city = input("What city are you from?")
print("Here is a list of professional %s teams in the city of %s" % (sport, city))
sport_teams.loc[(sport_teams["Sport"]==sport) & (sport_teams["City"]==city)]
# Out:
# enter your favorite sport (pick between Basketball, Soccer, Football, Baseball and Hockey):Basketball
# What city are you from?Denver
# Here is a list of professional Basketball teams in the city of Denver
#         Sport League    City     State            Name      Lat      Long
# 7  Basketball    NBA  Denver  Colorado  Denver Nuggets  39.7487 -105.0077

# %%
https://www.googleapis.com/geolocation/v1/geolocate?key=AIzaSyBGPrUO2TnedZZ3PJumc-ns_2EprRjMLqU
# Out:
#   File "<ipython-input-16-dbfdcc8fadde>", line 1
#     https://www.googleapis.com/geolocation/v1/geolocate?key=AIzaSyBGPrUO2TnedZZ3PJumc-ns_2EprRjMLqU
#            ^
# SyntaxError: invalid syntax
